# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("D:\Machine_Learning_Journey\EDA\Air_quality_EDA\globalAirQuality.csv")
df
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df.shape
# Out:
# (18000, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18000 entries, 0 to 17999
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   timestamp    18000 non-null  object
#  1   country      18000 non-null  object
#  2   city         18000 non-null  object
#  3   latitude     18000 non-null  float64
#  4   longitude    18000 non-null  float64
#  5   pm25         18000 non-null  float64
#  6   pm10         18000 non-null  float64
#  7   no2          18000 non-null  float64
#  8   so2          18000 non-null  float64
#  9   o3           18000 non-null  float64
#  10  co           18000 non-null  float64
#  11  aqi          18000 non-null  int64
#  12  temperature  18000 non-null  float64
#  13  humidity     18000 non-null  float64
#  14  wind_speed   18000 non-null  float64
# dtypes: float64(11), int64(1), object(3)
# memory usage: 2.1+ MB

# %%
df.describe()
# Out:
#            latitude     longitude          pm25          pm10           no2  \
# count  18000.000000  18000.000000  18000.000000  18000.000000  18000.000000
# mean      23.065980     37.655560     40.369131     70.152228     32.055176
# std       26.156536     78.600701     17.647450     24.999440     13.820680
# min      -37.814000   -123.121000      0.025000      0.061000      0.013000
# 25%       12.972000      2.352000     27.904500     53.125500     22.362500
# 50%       29.232000     42.146000     40.286500     69.961000     32.019500
# 75%       41.008000    103.820000     52.436250     87.256500     41.364250
# max       60.170000    174.763000    115.683000    161.810000     90.019000
#
#                 so2            o3            co           aqi   temperature  \
# count  18000.000000  18000.000000  18000.000000  18000.000000  18000.000000
# mean       6.035508     48.065100      0.800595    104.645556     21.510251
# ...

# %%
df
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df.isnull().sum()
# Out:
# timestamp      0
# country        0
# city           0
# latitude       0
# longitude      0
# pm25           0
# pm10           0
# no2            0
# so2            0
# o3             0
# co             0
# aqi            0
# temperature    0
# humidity       0
# wind_speed     0
# dtype: int64

# %%
df[df['aqi']==max(df['aqi'])]
# Out:
#                         timestamp country      city  latitude  longitude  \
# 17529  2025-11-15 03:25:17.554219      FI  Helsinki     60.17     24.938
#
#           pm25    pm10     no2    so2      o3     co  aqi  temperature  \
# 17529  115.683  81.714  54.764  6.687  39.552  0.685  231       25.795
#
#        humidity  wind_speed
# 17529    87.839       6.705

# %%
df['city'].unique()
# Out:
# array(['New York', 'Los Angeles', 'London', 'Paris', 'Berlin', 'Madrid',
#        'Rome', 'Toronto', 'Mexico City', 'São Paulo', 'Buenos Aires',
#        'Cape Town', 'Cairo', 'Nairobi', 'Lagos', 'Dubai', 'Riyadh',
#        'Doha', 'Mumbai', 'Delhi', 'Bengaluru', 'Kolkata', 'Chennai',
#        'Tokyo', 'Osaka', 'Seoul', 'Beijing', 'Shanghai', 'Hong Kong',
#        'Singapore', 'Bangkok', 'Kuala Lumpur', 'Jakarta', 'Sydney',
#        'Melbourne', 'Auckland', 'Moscow', 'Istanbul', 'Tehran', 'Karachi',
#        'Manila', 'Ho Chi Minh City', 'San Francisco', 'Chicago',
#        'Houston', 'Vancouver', 'Warsaw', 'Stockholm', 'Helsinki',
#        'Zurich'], dtype=object)

# %%
df.loc[0:2,['city','aqi']]
# Out:
#        city  aqi
# 0  New York  108
# 1  New York   90
# 2  New York   84

# %%
new_df=df.iloc[[2,34,4],[1,3,5]].copy()
new_df
# Out:
#    country  latitude    pm25
# 2       US    40.713  42.250
# 34      US    40.713  43.347
# 4       US    40.713  21.083

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

x = df['temperature']
y = df['humidity']

plt.figure(figsize=(8,5))
plt.scatter(x, y, s=8, alpha=0.5)

plt.xlabel("Temperature (°C)")
plt.ylabel("Humidity (%)")
plt.title("Temperature vs Humidity")

plt.grid(True)
plt.show()

# %%
df[['temperature', 'humidity']].corr()
# Out:
#              temperature  humidity
# temperature     1.000000 -0.011979
# humidity       -0.011979  1.000000

# %%
plt.boxplot(df['temperature'])
plt.title("Temperature boxplot")
plt.show()

# %%
df[df['aqi']>100][['city','aqi']]
# Out:
#            city  aqi
# 0      New York  108
# 3      New York  158
# 6      New York  155
# 7      New York  115
# 8      New York  121
# ...         ...  ...
# 17991    Zurich  104
# 17993    Zurich  153
# 17995    Zurich  103
# 17996    Zurich  105
# 17997    Zurich  122
#
# [9721 rows x 2 columns]

# %%
plt.boxplot(df['humidity'])
plt.title("Humidity boxplot")
plt.show()

# %%
value=100
df.query("aqi==@value")
# Out:
#                         timestamp country      city  latitude  longitude  \
# 141    2025-11-10 15:25:17.554219      US  New York    40.713    -74.006
# 155    2025-11-11 05:25:17.554219      US  New York    40.713    -74.006
# 234    2025-11-14 12:25:17.554219      US  New York    40.713    -74.006
# 241    2025-11-14 19:25:17.554219      US  New York    40.713    -74.006
# 280    2025-11-16 10:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17429  2025-11-10 23:25:17.554219      FI  Helsinki    60.170     24.938
# 17540  2025-11-15 14:25:17.554219      FI  Helsinki    60.170     24.938
# 17769  2025-11-10 03:25:17.554219      CH    Zurich    47.377      8.542
# 17830  2025-11-12 16:25:17.554219      CH    Zurich    47.377      8.542
# 17850  2025-11-13 12:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2     so2      o3     co  aqi  temperature  \
# ...

# %%
plt.hist(df['temperature'],bins=30)
# Out:
# (array([600., 593., 594., 626., 579., 579., 581., 601., 609., 622., 614.,
#         580., 597., 618., 633., 590., 574., 603., 603., 590., 640., 580.,
#         600., 609., 624., 587., 587., 564., 599., 624.]),
#  array([ 5.        ,  6.09993333,  7.19986667,  8.2998    ,  9.39973333,
#         10.49966667, 11.5996    , 12.69953333, 13.79946667, 14.8994    ,
#         15.99933333, 17.09926667, 18.1992    , 19.29913333, 20.39906667,
#         21.499     , 22.59893333, 23.69886667, 24.7988    , 25.89873333,
#         26.99866667, 28.0986    , 29.19853333, 30.29846667, 31.3984    ,
#         32.49833333, 33.59826667, 34.6982    , 35.79813333, 36.89806667,
#         37.998     ]),
#  <BarContainer object of 30 artists>)

# %%
new_df=df['aqi'].astype("int32").copy
new_df
# Out:
# <bound method NDFrame.copy of 0        108
# 1         90
# 2         84
# 3        158
# 4         97
#         ...
# 17995    103
# 17996    105
# 17997    122
# 17998     95
# 17999     88
# Name: aqi, Length: 18000, dtype: int32>

# %%
#Temperature vs Humidity
plt.scatter(df['temperature'],df['humidity'],alpha=0.3,s=80)
plt.xlabel("Temperature")
plt.ylabel("Humidity")

plt.show()

# %%
df['timestamp']=pd.to_datetime(df['timestamp'])
df['timestamp'].dtype
# Out:
# dtype('<M8[ns]')

# %%
plt.scatter(df['pm25'],df["aqi"],alpha=0.3,s=8)

plt.xlabel("PM2.5")
plt.ylabel("AQI")

plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#              latitude  longitude      pm25      pm10       no2       so2  \
# latitude     1.000000  -0.326934  0.000071  0.002831 -0.001264 -0.008259
# longitude   -0.326934   1.000000 -0.002588 -0.013217  0.007569  0.012564
# pm25         0.000071  -0.002588  1.000000 -0.005904 -0.002220  0.000701
# pm10         0.002831  -0.013217 -0.005904  1.000000 -0.003896 -0.008034
# no2         -0.001264   0.007569 -0.002220 -0.003896  1.000000  0.006108
# so2         -0.008259   0.012564  0.000701 -0.008034  0.006108  1.000000
# o3          -0.000654   0.000283  0.011293 -0.003277 -0.001936 -0.007127
# co          -0.003521   0.004280  0.006617  0.001398 -0.009992 -0.015675
# aqi         -0.001187  -0.008687  0.556094  0.207499  0.531731 -0.005202
# temperature  0.008167  -0.010885 -0.005003  0.012491  0.011003 -0.004727
# humidity    -0.005283   0.006083  0.004710 -0.001294 -0.003373  0.008162
# wind_speed   0.000570   0.003305 -0.006191  0.002896 -0.000878 -0.006751
#
# ...

# %%
df['country'].value_counts().head().plot(kind='bar')
plt.xlabel("Country")
plt.ylabel("count")
plt.show()

# %%
df['city'].str.capitalize()
# Out:
# 0        New york
# 1        New york
# 2        New york
# 3        New york
# 4        New york
#            ...
# 17995      Zurich
# 17996      Zurich
# 17997      Zurich
# 17998      Zurich
# 17999      Zurich
# Name: city, Length: 18000, dtype: object

# %%
df['city'].str.split(" ")
# Out:
# 0        [New, York]
# 1        [New, York]
# 2        [New, York]
# 3        [New, York]
# 4        [New, York]
#             ...
# 17995       [Zurich]
# 17996       [Zurich]
# 17997       [Zurich]
# 17998       [Zurich]
# 17999       [Zurich]
# Name: city, Length: 18000, dtype: object
